# %% [markdown]
# # LLM Structured Prompt Outline

# %% [markdown]
# ```mermaid
# ---
# config:
#     htmlLabels: true
#     layout: elk
#     theme: 'base'
#     themeVariables:
#         fontSize: '20px'
#     elk:
#         mergeEdges: true
# ---
# flowchart TB
#
#     text_label(Text)
#     text_input[&quot;The elements Ba, Zn, and As in a 2:5:6 molar ratio were loaded into carbonized silica ampoules&quot;]
#     json_label(JSON)
#     json_input@{ img: "./assets/json_example_input.png", h: 200, constraint: "on" }
#     xcl_label(Spreadsheet)
#     xcl_input@{ img: "./assets/spreadsheet_BaZnAs_example_1.png", h: 200, constraint: "on" }
#
#     prompt_label{Abstract<br>Tokenization}
#
#     token1@{ img: "./assets/token_examples/ex (1).png", h: 60, constraint: "on" }
#     token2@{ img: "./assets/token_examples/ex (2).png", h: 60, constraint: "on" }
#     token3@{ img: "./assets/token_examples/ex (3).png", h: 60, constraint: "on" }
#     token4@{ img: "./assets/token_examples/ex (4).png", h: 60, constraint: "on" }
#     token5@{ img: "./assets/token_examples/ex (5).png", h: 60, constraint: "on" }
#     token6@{ img: "./assets/token_examples/ex (6).png", h: 60, constraint: "on" }
#     token7@{ img: "./assets/token_examples/ex (7).png", h: 60, constraint: "on" }
#     token8@{ img: "./assets/token_examples/ex (8).png", h: 60, constraint: "on" }
#
#     subgraph tokens [ ]
#         direction LR
#
#         token1 ~~~ token8
#         token2 ~~~ token3
#         token4 ~~~ token5
#         token6 ~~~ token7
#     end
#
#
#     text_label --- text_input --> prompt_label
#     json_label --- json_input --> prompt_label
#     xcl_label --- xcl_input --> prompt_label
#     prompt_label --> tokens
#
# ```

# %% [markdown]
# ````mermaid
# ---
# config:
#     htmlLabels: true
#     layout: elk
#     theme: 'base'
#     themeVariables:
#         fontSize: '20px'
#     elk:
#         mergeEdges: True
#         nodePlacementStrategy: 'SIMPLE'
# ---
# flowchart LR
#     token1@{ img: "./assets/token_examples/ex (1).png", h: 60, constraint: "on" }
#     token2@{ img: "./assets/token_examples/ex (2).png", h: 60, constraint: "on" }
#     token3@{ img: "./assets/token_examples/ex (3).png", h: 60, constraint: "on" }
#     token4@{ img: "./assets/token_examples/ex (4).png", h: 60, constraint: "on" }
#     token5@{ img: "./assets/token_examples/ex (5).png", h: 60, constraint: "on" }
#     token6@{ img: "./assets/token_examples/ex (6).png", h: 60, constraint: "on" }
#     token7@{ img: "./assets/token_examples/ex (7).png", h: 60, constraint: "on" }
#     token8@{ img: "./assets/token_examples/ex (8).png", h: 60, constraint: "on" }
#
#     subgraph syn [Synthesis Properties]
#         treats[Treatments]
#
#         mats[Materials]
#     end
#
#     token2 --- token3
#     token4 --- token5
#     token6 --- token7
#
#     token1 --> mats
#     token8 --> treats
#     token3 --> mats
#     token5 --> mats
#     token7 --> mats
#
#
#
# ````

# %% [markdown]
# ````mermaid
# ---
# config:
#     htmlLabels: true
#     layout: elk
#     theme: 'base'
#     themeVariables:
#         fontSize: '20px'
#     elk:
#         mergeEdges: True
#         nodePlacementStrategy: 'SIMPLE'
# ---
# flowchart LR
#     token1@{ img: "./assets/token_examples/ex (1).png", h: 60, constraint: "on" }
#     token2@{ img: "./assets/token_examples/ex (2).png", h: 60, constraint: "on" }
#     token3@{ img: "./assets/token_examples/ex (3).png", h: 60, constraint: "on" }
#     token4@{ img: "./assets/token_examples/ex (4).png", h: 60, constraint: "on" }
#     token5@{ img: "./assets/token_examples/ex (5).png", h: 60, constraint: "on" }
#     token6@{ img: "./assets/token_examples/ex (6).png", h: 60, constraint: "on" }
#     token7@{ img: "./assets/token_examples/ex (7).png", h: 60, constraint: "on" }
#     token8@{ img: "./assets/token_examples/ex (8).png", h: 60, constraint: "on" }
#
#     subgraph syn [Synthesis Properties]
#         treats[Treatments]
#
#         subgraph mats [Materials]
#             m0[0]
#             m1[1]
#             m2[2]
#         end
#     end
#
#     token2 --- token3
#     token4 --- token5
#     token6 --- token7
#
#     token1 --> mats
#
#     token8 --> treats
#     token3 --> m0
#     token5 --> m1
#     token7 --> m2
#
#
#
# ````

# %% [markdown]
# ```mermaid
# ---
# config:
#     htmlLabels: true
#     layout: elk
#     theme: 'base'
#     themeVariables:
#         fontSize: '20px'
#     elk:
#         mergeEdges: True
#         nodePlacementStrategy: 'NETWORK_SIMPLEX'
# ---
# flowchart LR
#
#     token1@{ img: "./assets/token_examples/ex (1).png", h: 60, constraint: "on" }
#     token6@{ img: "./assets/token_examples/ex (6).png", h: 60, constraint: "on" }
#     token7@{ img: "./assets/token_examples/ex (7).png", h: 60, constraint: "on" }
#
#     mat0[Material 0]
#     mat1[Material 1]
#     subgraph mat2 [Material 2]
#         form["`**formula:** As`"]
#         amt["`**amount:** 6`"]
#         amt_unit["`**amount_unit:** mol ratio`"]
#     end
#
#     token1 --> mat0
#     token1 --> mat1
#     token1 --> amt_unit
#
#     token6 --> form
#     token7 --> amt
#
# ```
